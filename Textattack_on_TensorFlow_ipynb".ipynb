# %% [markdown]
# <a href="https://colab.research.google.com/github/kolayn808/textattack_test/blob/main/Textattack_on_TensorFlow_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Установка Textattack

# %%
# !git clone https://github.com/QData/TextAttack.git
# Out:
# Cloning into 'TextAttack'...
# remote: Enumerating objects: 21081, done.
# remote: Counting objects: 100% (546/546), done.
# remote: Compressing objects: 100% (290/290), done.
# remote: Total 21081 (delta 314), reused 403 (delta 253), pack-reused 20535
# Receiving objects: 100% (21081/21081), 25.85 MiB | 29.54 MiB/s, done.
# Resolving deltas: 100% (15619/15619), done.

# %%
# %cd /content/TextAttack
# !pip install -e .
# Out:
# /content/TextAttack
# Obtaining file:///content/TextAttack
#   Preparing metadata (setup.py) ... done
# Collecting bert-score>=0.3.5 (from textattack==0.3.9)
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (0.6.2)
# Collecting flair (from textattack==0.3.9)
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (3.12.4)
# Collecting language_tool_python (from textattack==0.3.9)
#   Downloading language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# Collecting lemminflect (from textattack==0.3.9)
#   Downloading lemminflect-0.2.3-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 30.9 MB/s eta 0:00:00
# Collecting lru-dict (from textattack==0.3.9)
#   Downloading lru_dict-1.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Collecting datasets>=2.4.0 (from textattack==0.3.9)
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (3.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (1.23.5)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (1.5.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (1.11.3)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (2.1.0+cu118)
# Collecting transformers>=4.30.0 (from textattack==0.3.9)
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 60.4 MB/s eta 0:00:00
# Collecting terminaltables (from textattack==0.3.9)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (4.66.1)
# Collecting word2number (from textattack==0.3.9)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting num2words (from textattack==0.3.9)
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (10.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (1.7.1)
# Collecting pinyin>=0.4.0 (from textattack==0.3.9)
#   Downloading pinyin-0.4.0.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 49.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from textattack==0.3.9) (0.42.1)
# Collecting OpenHowNet (from textattack==0.3.9)
#   Downloading OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Collecting pycld2 (from textattack==0.3.9)
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting click<8.1.0 (from textattack==0.3.9)
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack==0.3.9) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack==0.3.9) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack==0.3.9) (23.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack==0.3.9) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=2.4.0->textattack==0.3.9)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack==0.3.9) (3.4.1)
# Collecting multiprocess (from datasets>=2.4.0->textattack==0.3.9)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack==0.3.9) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack==0.3.9) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets>=2.4.0->textattack==0.3.9)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack==0.3.9) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack==0.3.9) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack==0.3.9) (2023.3.post1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack==0.3.9) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack==0.3.9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack==0.3.9) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack==0.3.9) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack==0.3.9) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack==0.3.9) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.30.0->textattack==0.3.9)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 8.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.30.0->textattack==0.3.9)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 91.0 MB/s eta 0:00:00
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack==0.3.9) (4.3.2)
# Collecting segtok>=1.5.7 (from flair->textattack==0.3.9)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting mpld3==0.3 (from flair->textattack==0.3.9)
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 73.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack==0.3.9) (1.2.2)
# Collecting sqlitedict>=1.6.0 (from flair->textattack==0.3.9)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated>=1.2.4 (from flair->textattack==0.3.9)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack==0.3.9) (0.2.7)
# Collecting boto3 (from flair->textattack==0.3.9)
#   Downloading boto3-1.28.66-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 16.2 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2 (from flair->textattack==0.3.9)
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from flair->textattack==0.3.9) (0.9.0)
# Collecting langdetect (from flair->textattack==0.3.9)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 61.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from flair->textattack==0.3.9) (4.9.3)
# Collecting ftfy (from flair->textattack==0.3.9)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.1 MB/s eta 0:00:00
# Collecting janome (from flair->textattack==0.3.9)
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 60.8 MB/s eta 0:00:00
# Collecting gdown==4.4.0 (from flair->textattack==0.3.9)
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting conllu>=4.0 (from flair->textattack==0.3.9)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Collecting wikipedia-api (from flair->textattack==0.3.9)
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting pptree (from flair->textattack==0.3.9)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-revgrad (from flair->textattack==0.3.9)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting transformer-smaller-training-vocab>=0.2.1 (from flair->textattack==0.3.9)
#   Downloading transformer_smaller_training_vocab-0.3.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair->textattack==0.3.9) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair->textattack==0.3.9) (4.11.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->textattack==0.3.9) (1.3.2)
# Collecting docopt>=0.6.2 (from num2words->textattack==0.3.9)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting anytree (from OpenHowNet->textattack==0.3.9)
#   Downloading anytree-2.10.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from OpenHowNet->textattack==0.3.9) (67.7.2)
# Collecting sentencepiece (from bpemb>=0.3.2->flair->textattack==0.3.9)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.4 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.4->flair->textattack==0.3.9) (1.15.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack==0.3.9) (1.3.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.8.0->flair->textattack==0.3.9) (6.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack==0.3.9) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack==0.3.9) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack==0.3.9) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack==0.3.9) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack==0.3.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack==0.3.9) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack==0.3.9) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack==0.3.9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack==0.3.9) (3.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack==0.3.9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack==0.3.9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack==0.3.9) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->flair->textattack==0.3.9) (3.2.0)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets>=2.4.0->textattack==0.3.9)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack==0.3.9) (3.20.3)
# Collecting botocore<1.32.0,>=1.31.66 (from boto3->flair->textattack==0.3.9)
#   Downloading botocore-1.31.66-py3-none-any.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 103.3 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->flair->textattack==0.3.9)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3->flair->textattack==0.3.9)
#   Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->flair->textattack==0.3.9) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack==0.3.9) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.7.0->textattack==0.3.9) (1.3.0)
# Collecting accelerate>=0.20.3 (from transformers>=4.30.0->textattack==0.3.9)
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack==0.3.9) (2.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers>=4.30.0->textattack==0.3.9) (5.9.5)
# Building wheels for collected packages: pinyin, gdown, mpld3, pycld2, word2number, docopt, sqlitedict, langdetect, pptree
#   Building wheel for pinyin (setup.py) ... done
#   Created wheel for pinyin: filename=pinyin-0.4.0-py3-none-any.whl size=3630475 sha256=f27afa28d7a4a0c6be6adb9b25849b418e6d754f428da4dba3164580d82732ca
#   Stored in directory: /root/.cache/pip/wheels/33/38/af/616fc6f154aa5bae65a1da12b22d79943434269f0468ff9b3f
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14758 sha256=5c7ec1ffede234bd86c6be27958badeb925bcc4cb5c81affc41344ed00b7ece6
#   Stored in directory: /root/.cache/pip/wheels/03/0b/3f/6ddf67a417a5b400b213b0bb772a50276c199a386b12c06bfc
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116686 sha256=0faf148a37cc6358e750def23dc00f0a4e1b7333d80039f4b77b6722adae5270
#   Stored in directory: /root/.cache/pip/wheels/9c/92/f7/45d9aac5dcfb1c2a1761a272365599cc7ba1050ce211a3fd9a
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp310-cp310-linux_x86_64.whl size=9904035 sha256=5cf01f28dbe9ac8908217b06c5dfcaafc531d48008c8be0b3d84351df9acb6de
#   Stored in directory: /root/.cache/pip/wheels/be/81/31/240c89c845e008a93d98542325270007de595bfd356eb0b06c
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5567 sha256=9e81f6cb409ca8edc646eb411779cf2b126049155685961ed2ac042728b4a64c
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=564344578194930ddcc9af84edef5b21895256e05434ae787e65c25b835aa438
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16864 sha256=b85dcbe5ec74d71bfe1a477238c0b05fd4deeaa48e279484f449ede475d5b6d1
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=537bf5f1dc28c34f4d5d1c2f9d6d9b124ef8946302a148fa18a2e1f2c5de7b2e
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4609 sha256=152a674c0504f1f5a176a81b204bbc49299eef96d9abed9907dae44d15f6f2cd
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
# Successfully built pinyin gdown mpld3 pycld2 word2number docopt sqlitedict langdetect pptree
# Installing collected packages: word2number, sqlitedict, sentencepiece, pycld2, pptree, pinyin, mpld3, lru-dict, janome, docopt, terminaltables, segtok, safetensors, num2words, lemminflect, langdetect, jmespath, ftfy, dill, deprecated, conllu, click, anytree, wikipedia-api, OpenHowNet, multiprocess, language_tool_python, huggingface-hub, botocore, tokenizers, s3transfer, pytorch-revgrad, gdown, bpemb, accelerate, transformers, datasets, boto3, bert-score, transformer-smaller-training-vocab, flair, textattack
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
#   Running setup.py develop for textattack
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed OpenHowNet-2.0 accelerate-0.23.0 anytree-2.10.0 bert-score-0.3.13 boto3-1.28.66 botocore-1.31.66 bpemb-0.3.4 click-8.0.4 conllu-4.5.3 datasets-2.14.5 deprecated-1.2.14 dill-0.3.7 docopt-0.6.2 flair-0.12.2 ftfy-6.1.1 gdown-4.4.0 huggingface-hub-0.17.3 janome-0.5.0 jmespath-1.0.1 langdetect-1.0.9 language_tool_python-2.7.1 lemminflect-0.2.3 lru-dict-1.2.0 mpld3-0.3 multiprocess-0.70.15 num2words-0.5.13 pinyin-0.4.0 pptree-3.1 pycld2-0.41 pytorch-revgrad-0.2.0 s3transfer-0.7.0 safetensors-0.4.0 segtok-1.5.11 sentencepiece-0.1.99 sqlitedict-2.1.0 terminaltables-3.1.10 textattack-0.3.9 tokenizers-0.14.1 transformer-smaller-training-vocab-0.3.2 transformers-4.34.1 wikipedia-api-0.6.0 word2number-1.1

# %% [markdown]
# Импорт модели

# %%
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds

import matplotlib.pyplot as plt

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

train_data, test_data = tfds.load(name="imdb_reviews", split=["train", "test"],
                                  batch_size=-1, as_supervised=True)

train_examples, train_labels = tfds.as_numpy(train_data)
test_examples, test_labels = tfds.as_numpy(test_data)

model = "https://tfhub.dev/google/tf2-preview/gnews-swivel-20dim/1"
hub_layer = hub.KerasLayer(model, output_shape=[20], input_shape=[],
                           dtype=tf.string, trainable=True)
hub_layer(train_examples[:3])

model = tf.keras.Sequential()
model.add(hub_layer)
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(1))

model.summary()

x_val = train_examples[:10000]
partial_x_train = train_examples[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

model.compile(optimizer='adam',
              loss=tf.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Version:  2.13.0
# Eager mode:  True
# Hub version:  0.15.0
# GPU is available
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incomplete91RQDT/imdb_reviews-train.tfrecord…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incomplete91RQDT/imdb_reviews-test.tfrecord*…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incomplete91RQDT/imdb_reviews-unsupervised.t…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 20)                400020
#
#  dense (Dense)               (None, 16)                336
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 400373 (1.53 MB)
# Trainable params: 400373 (1.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 30/30 [==============================] - 14s 280ms/step - loss: 0.6787 - accuracy: 0.5396 - val_loss: 0.6468 - val_accuracy: 0.5603
# Epoch 2/40
# 30/30 [==============================] - 8s 277ms/step - loss: 0.6219 - accuracy: 0.6064 - val_loss: 0.6088 - val_accuracy: 0.6282
# Epoch 3/40
# 30/30 [==============================] - 8s 251ms/step - loss: 0.5837 - accuracy: 0.6594 - val_loss: 0.5736 - val_accuracy: 0.6697
# Epoch 4/40
# 30/30 [==============================] - 7s 250ms/step - loss: 0.5420 - accuracy: 0.7059 - val_loss: 0.5360 - val_accuracy: 0.7058
# Epoch 5/40
# 30/30 [==============================] - 7s 222ms/step - loss: 0.5007 - accuracy: 0.7389 - val_loss: 0.5022 - val_accuracy: 0.7395
# Epoch 6/40
# 30/30 [==============================] - 6s 190ms/step - loss: 0.4617 - accuracy: 0.7721 - val_loss: 0.4714 - val_accuracy: 0.7643
# Epoch 7/40
# 30/30 [==============================] - 7s 248ms/step - loss: 0.4249 - accuracy: 0.7981 - val_loss: 0.4441 - val_accuracy: 0.7831
# Epoch 8/40
# 30/30 [==============================] - 5s 159ms/step - loss: 0.3913 - accuracy: 0.8200 - val_loss: 0.4214 - val_accuracy: 0.8030
# Epoch 9/40
# 30/30 [==============================] - 5s 163ms/step - loss: 0.3599 - accuracy: 0.8361 - val_loss: 0.3996 - val_accuracy: 0.8108
# Epoch 10/40
# 30/30 [==============================] - 7s 240ms/step - loss: 0.3343 - accuracy: 0.8484 - val_loss: 0.3831 - val_accuracy: 0.8255
# Epoch 11/40
# 30/30 [==============================] - 6s 212ms/step - loss: 0.3079 - accuracy: 0.8645 - val_loss: 0.3694 - val_accuracy: 0.8320
# Epoch 12/40
# 30/30 [==============================] - 6s 179ms/step - loss: 0.2859 - accuracy: 0.8759 - val_loss: 0.3576 - val_accuracy: 0.8355
# Epoch 13/40
# 30/30 [==============================] - 4s 146ms/step - loss: 0.2664 - accuracy: 0.8852 - val_loss: 0.3484 - val_accuracy: 0.8391
# Epoch 14/40
# 30/30 [==============================] - 5s 182ms/step - loss: 0.2475 - accuracy: 0.8940 - val_loss: 0.3426 - val_accuracy: 0.8565
# Epoch 15/40
# 30/30 [==============================] - 6s 182ms/step - loss: 0.2329 - accuracy: 0.9037 - val_loss: 0.3343 - val_accuracy: 0.8561
# Epoch 16/40
# 30/30 [==============================] - 6s 191ms/step - loss: 0.2169 - accuracy: 0.9119 - val_loss: 0.3300 - val_accuracy: 0.8588
# Epoch 17/40
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2044 - accuracy: 0.9183 - val_loss: 0.3272 - val_accuracy: 0.8612
# Epoch 18/40
# 30/30 [==============================] - 6s 189ms/step - loss: 0.1911 - accuracy: 0.9256 - val_loss: 0.3245 - val_accuracy: 0.8597
# Epoch 19/40
# 30/30 [==============================] - 5s 153ms/step - loss: 0.1797 - accuracy: 0.9285 - val_loss: 0.3243 - val_accuracy: 0.8593
# Epoch 20/40
# 30/30 [==============================] - 3s 103ms/step - loss: 0.1687 - accuracy: 0.9344 - val_loss: 0.3222 - val_accuracy: 0.8627
# Epoch 21/40
# 30/30 [==============================] - 4s 139ms/step - loss: 0.1595 - accuracy: 0.9388 - val_loss: 0.3227 - val_accuracy: 0.8650
# Epoch 22/40
# 30/30 [==============================] - 4s 140ms/step - loss: 0.1500 - accuracy: 0.9434 - val_loss: 0.3234 - val_accuracy: 0.8664
# Epoch 23/40
# 30/30 [==============================] - 3s 115ms/step - loss: 0.1399 - accuracy: 0.9487 - val_loss: 0.3253 - val_accuracy: 0.8650
# Epoch 24/40
# 30/30 [==============================] - 4s 135ms/step - loss: 0.1319 - accuracy: 0.9517 - val_loss: 0.3305 - val_accuracy: 0.8698
# Epoch 25/40
# 30/30 [==============================] - 5s 177ms/step - loss: 0.1246 - accuracy: 0.9560 - val_loss: 0.3306 - val_accuracy: 0.8694
# Epoch 26/40
# 30/30 [==============================] - 3s 89ms/step - loss: 0.1164 - accuracy: 0.9597 - val_loss: 0.3350 - val_accuracy: 0.8638
# Epoch 27/40
# 30/30 [==============================] - 3s 96ms/step - loss: 0.1102 - accuracy: 0.9620 - val_loss: 0.3390 - val_accuracy: 0.8694
# Epoch 28/40
# 30/30 [==============================] - 4s 121ms/step - loss: 0.1032 - accuracy: 0.9650 - val_loss: 0.3429 - val_accuracy: 0.8687
# Epoch 29/40
# 30/30 [==============================] - 6s 191ms/step - loss: 0.0964 - accuracy: 0.9687 - val_loss: 0.3470 - val_accuracy: 0.8675
# Epoch 30/40
# 30/30 [==============================] - 3s 118ms/step - loss: 0.0906 - accuracy: 0.9703 - val_loss: 0.3520 - val_accuracy: 0.8680
# Epoch 31/40
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0845 - accuracy: 0.9750 - val_loss: 0.3579 - val_accuracy: 0.8626
# Epoch 32/40
# 30/30 [==============================] - 3s 90ms/step - loss: 0.0798 - accuracy: 0.9759 - val_loss: 0.3632 - val_accuracy: 0.8637
# Epoch 33/40
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0753 - accuracy: 0.9779 - val_loss: 0.3703 - val_accuracy: 0.8664
# Epoch 34/40
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0699 - accuracy: 0.9810 - val_loss: 0.3755 - val_accuracy: 0.8638
# Epoch 35/40
# 30/30 [==============================] - 2s 75ms/step - loss: 0.0650 - accuracy: 0.9835 - val_loss: 0.3830 - val_accuracy: 0.8653
# Epoch 36/40
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0612 - accuracy: 0.9845 - val_loss: 0.3887 - val_accuracy: 0.8648
# Epoch 37/40
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0569 - accuracy: 0.9864 - val_loss: 0.3989 - val_accuracy: 0.8649
# Epoch 38/40
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0535 - accuracy: 0.9885 - val_loss: 0.4028 - val_accuracy: 0.8648
# Epoch 39/40
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0497 - accuracy: 0.9897 - val_loss: 0.4107 - val_accuracy: 0.8605
# Epoch 40/40
# 30/30 [==============================] - 3s 96ms/step - loss: 0.0464 - accuracy: 0.9909 - val_loss: 0.4181 - val_accuracy: 0.8630

# %%
import numpy as np
import torch

from textattack.models.wrappers import ModelWrapper

class CustomTensorFlowModelWrapper(ModelWrapper):
    def __init__(self, model):
        self.model = model

    def __call__(self, text_input_list):
        text_array = np.array(text_input_list)
        preds = self.model(text_array).numpy()
        logits = torch.exp(-torch.tensor(preds))
        logits = 1 / (1 + logits)
        logits = logits.squeeze(dim=-1)
        # Since this model only has a single output (between 0 or 1),
        # we have to add the second dimension.
        final_preds = torch.stack((1-logits, logits), dim=1)
        return final_preds
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
CustomTensorFlowModelWrapper(model)(['I hate you so much', 'I love you'])
# Out:
# tensor([[0.2203, 0.7797],
#         [0.0101, 0.9899]])

# %%
model_wrapper = CustomTensorFlowModelWrapper(model)

from textattack.datasets import HuggingFaceDataset
from textattack.attack_recipes import PWWSRen2019
from textattack import Attacker

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test", shuffle=True)
attack = PWWSRen2019.build(model_wrapper)

attacker = Attacker(attack, dataset)
attacker.attack_dataset()
# Out:
# Downloading builder script:   0%|          | 0.00/5.03k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.02k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.25k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/488k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# textattack: Loading datasets dataset rotten_tomatoes, split test.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# textattack: Unknown if model of class <class 'keras.src.engine.sequential.Sequential'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  weighted-saliency
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapWordNet
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# [Succeeded / Failed / Skipped / Total] 0 / 0 / 1 / 1:  10%|█         | 1/10 [00:00<00:00, 38.04it/s]
# --------------------------------------------- Result 1 ---------------------------------------------
# [[Negative (82%)]] --> [[[SKIPPED]]]
#
# lovingly photographed in the manner of a golden book sprung to life , stuart little 2 manages sweetness largely without stickiness .
#
#
# --------------------------------------------- Result 2 ---------------------------------------------
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  4.00it/s]
# [[Positive (52%)]] --> [[Negative (95%)]]
#
# consistently clever and [[suspenseful]] .
#
# consistently clever and [[cliff-hanging]] .
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 3 / 6:  60%|██████    | 6/10 [00:00<00:00,  6.72it/s]
# --------------------------------------------- Result 3 ---------------------------------------------
# [[Positive (99%)]] --> [[Negative (69%)]]
#
# it's like a " [[big]] chill " reunion of the baader-meinhof gang , only these [[guys]] are more harmless pranksters than political activists .
#
# it's like a " [[bad]] chill " reunion of the baader-meinhof gang , only these [[cat]] are more harmless pranksters than political activists .
#
#
# --------------------------------------------- Result 4 ---------------------------------------------
# [[Negative (75%)]] --> [[[SKIPPED]]]
#
# the story gives ample opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .
#
#
# --------------------------------------------- Result 5 ---------------------------------------------
# [[Negative (95%)]] --> [[[SKIPPED]]]
#
# red dragon " never cuts corners .
#
#
# --------------------------------------------- Result 6 ---------------------------------------------
# [[Positive (100%)]] --> [[Negative (87%)]]
#
# fresnadillo has something serious to say about the ways in which [[extravagant]] chance can distort our perspective and throw us off the [[path]] of [[good]] sense .
#
# fresnadillo has something serious to say about the ways in which [[exuberant]] chance can distort our perspective and throw us off the [[itinerary]] of [[honorable]] sense .
# [Succeeded / Failed / Skipped / Total] 6 / 0 / 4 / 10: 100%|██████████| 10/10 [00:01<00:00,  8.35it/s]
# --------------------------------------------- Result 7 ---------------------------------------------
# [[Positive (100%)]] --> [[Negative (91%)]]
#
# [[throws]] in enough clever and unexpected [[twists]] to make the formula feel fresh .
#
# [[drop]] in enough clever and unexpected [[device]] to make the formula feel fresh .
#
#
# --------------------------------------------- Result 8 ---------------------------------------------
# [[Positive (95%)]] --> [[Negative (70%)]]
#
# weighty and ponderous but every [[bit]] as filling as the treat of the title .
#
# weighty and ponderous but every [[bite]] as filling as the treat of the title .
#
#
# --------------------------------------------- Result 9 ---------------------------------------------
# [[Positive (82%)]] --> [[Negative (66%)]]
#
# a [[real]] audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
#
# a [[material]] audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
#
#
# --------------------------------------------- Result 10 ---------------------------------------------
# [[Negative (95%)]] --> [[[SKIPPED]]]
#
# generates an enormous feeling of empathy for its characters .
#
#
#
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 0      |
# | Number of skipped attacks:    | 4      |
# | Original accuracy:            | 60.0%  |
# | Accuracy under attack:        | 0.0%   |
# | Attack success rate:          | 100.0% |
# | Average perturbed word %:     | 12.18% |
# | Average num. words per input: | 15.4   |
# | Avg num queries:              | 132.5  |
# +-------------------------------+--------+
# [<textattack.attack_results.skipped_attack_result.SkippedAttackResult at 0x7dedce3e6140>,
#  <textattack.attack_results.successful_attack_result.SuccessfulAttackResult at 0x7dedce3e4ac0>,
#  <textattack.attack_results.successful_attack_result.SuccessfulAttackResult at 0x7dedce77ca00>,
#  <textattack.attack_results.skipped_attack_result.SkippedAttackResult at 0x7def71e05120>,
#  <textattack.attack_results.skipped_attack_result.SkippedAttackResult at 0x7dedce77f730>,
#  <textattack.attack_results.successful_attack_result.SuccessfulAttackResult at 0x7dedce77fa60>,
#  <textattack.attack_results.successful_attack_result.SuccessfulAttackResult at 0x7dedce77d600>,
#  <textattack.attack_results.successful_attack_result.SuccessfulAttackResult at 0x7dedcdf10340>,
#  <textattack.attack_results.successful_attack_result.SuccessfulAttackResult at 0x7dedcdf125c0>,
#  <textattack.attack_results.skipped_attack_result.SkippedAttackResult at 0x7dedcdf12470>]
